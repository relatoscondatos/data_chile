# %%
import os
import sys
import pandas as pd
import requests
from collections import defaultdict

# %%
# Check if running in the GitHub Actions environment
if 'GITHUB_ACTIONS' in os.environ:
    project_path = os.getcwd()
else:
    # Assuming your script is in the 'scripts' directory
    project_path = os.path.abspath(os.path.join(os.getcwd(), '../../..'))

# Add the project directory to the PYTHONPATH if it's not already there
if project_path not in sys.path:
    sys.path.append(project_path)

# Now you can import your custom module
from data_utils.data_processing import download_file, process_zip_file

# %%
from data_utils.data_processing import download_file, read_csv_file

# %%
def get_data_paths():
    # Check if running in the GitHub Actions environment
    if 'GITHUB_ACTIONS' in os.environ:
        base_path = os.path.join(os.getcwd(), 'data')
    else:
        # Assuming your script is in the 'scripts' directory
        base_path = os.path.abspath(os.path.join(os.getcwd(), '../../../data'))

    source_path = os.path.join(base_path, "source/ine/empleo")
    processed_path = os.path.join(base_path, "processed/ine/empleo")
    
    return source_path, processed_path

# %%
source_dir, processed_dir = get_data_paths()

print(f"Source dir: {source_dir}")
print(f"Processed dir: {processed_dir}")
# Out:
# Source dir: /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo
# Processed dir: /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo

# %%
os.makedirs(source_dir, exist_ok=True)
os.makedirs(processed_dir, exist_ok=True)

# %%
# List of file URLs
file_urls = [
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2024/csv/ene-2024-04-mam.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2024/csv/ene-2024-03-fma.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2024/csv/ene-2024-02-efm.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2024/csv/ene-2024-01-def.csv",

    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-12-nde.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-11-ond.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-10-son.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-09-aso.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-08-jas.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-07-jja.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-06-mjj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-05-amj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-04-mam.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-03-fma.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-02-efm.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-01-def.csv",

    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-12-nde.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-11-ond.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-10-son.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-09-aso.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-08-jas.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-07-jja.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-06-mjj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-05-amj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-04-mam.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-03-fma.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-02-efm.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-01-def.csv",

    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-12-nde.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-11-ond.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-10-son.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-09-aso.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-08-jas.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-07-jja.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-06-mjj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-05-amj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-04-mam.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-03-fma.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-02-efm.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-01-def.csv",

    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-12-nde.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-11-ond.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-10-son.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-09-aso.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-08-jas.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-07-jja.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-06-mjj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-05-amj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-04-mam.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-03-fma.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-02-efm.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-01-def.csv",

    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-12-nde.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-11-ond.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-10-son.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-09-aso.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-08-jas.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-07-jja.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-06-mjj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-05-amj.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-04-mam.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-03-fma.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-02-efm.csv",
    "https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-01-def.csv",
    # Add more URLs as needed
]

# %%
delimiter = ";"

# %%
# Function to preprocess the "fact_cal" field
def preprocess_fact_cal(df):
    if 'fact_cal' in df.columns:
        df['fact_cal'] = df['fact_cal'].str.replace(',', '.').astype(float)
    return df

# %%
# Dictionary to store DataFrames for each trimester
trimester_data = defaultdict(pd.DataFrame)

# %%
# Download files and group by trimester
for url in file_urls:
    # Extract filename from URL
    filename = url.split('/')[-1]
    csv_path = os.path.join(source_dir, filename)
    
    print(f"Next {url}")
    # Check if the file already exists
    if not os.path.exists(csv_path):
        # Download the CSV file if it doesn't exist
        download_file(url, csv_path)
        print(f"Downloaded {filename}")
    else:
        print(f"{filename} already exists. Skipping download.")
    
    # Read the CSV file
    df = read_csv_file(csv_path, delimiter=delimiter)
    
    # Preprocess the "fact_cal" field
    df = preprocess_fact_cal(df)
    
    # Extract trimester info (e.g., "04-mam" from "ene-2024-04-mam.csv")
    trimester = '-'.join(filename.split('-')[2:4]).split('.')[0]
    
    # Append data to the corresponding trimester DataFrame
    trimester_data[trimester] = pd.concat([trimester_data[trimester], df], ignore_index=True)
    
    print(f"Added {filename} to the trimester {trimester} DataFrame.")
# Out:
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2024/csv/ene-2024-04-mam.csv
# ene-2024-04-mam.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2024-04-mam.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2024-04-mam.csv to the trimester 04-mam DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2024/csv/ene-2024-03-fma.csv
# ene-2024-03-fma.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2024-03-fma.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2024-03-fma.csv to the trimester 03-fma DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2024/csv/ene-2024-02-efm.csv
# ene-2024-02-efm.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2024-02-efm.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2024-02-efm.csv to the trimester 02-efm DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2024/csv/ene-2024-01-def.csv
# ene-2024-01-def.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2024-01-def.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2024-01-def.csv to the trimester 01-def DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-12-nde.csv
# ene-2023-12-nde.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-12-nde.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-12-nde.csv to the trimester 12-nde DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-11-ond.csv
# ene-2023-11-ond.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-11-ond.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-11-ond.csv to the trimester 11-ond DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-10-son.csv
# ene-2023-10-son.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-10-son.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-10-son.csv to the trimester 10-son DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-09-aso.csv
# ene-2023-09-aso.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-09-aso.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-09-aso.csv to the trimester 09-aso DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-08-jas.csv
# ene-2023-08-jas.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-08-jas.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-08-jas.csv to the trimester 08-jas DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-07-jja.csv
# ene-2023-07-jja.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-07-jja.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-07-jja.csv to the trimester 07-jja DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-06-mjj.csv
# ene-2023-06-mjj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-06-mjj.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-06-mjj.csv to the trimester 06-mjj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-05-amj.csv
# ene-2023-05-amj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-05-amj.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-05-amj.csv to the trimester 05-amj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-04-mam.csv
# ene-2023-04-mam.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-04-mam.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-04-mam.csv to the trimester 04-mam DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-03-fma.csv
# ene-2023-03-fma.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-03-fma.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-03-fma.csv to the trimester 03-fma DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-02-efm.csv
# ene-2023-02-efm.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-02-efm.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-02-efm.csv to the trimester 02-efm DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2023/csv/ene-2023-01-def.csv
# ene-2023-01-def.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2023-01-def.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2023-01-def.csv to the trimester 01-def DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-12-nde.csv
# ene-2022-12-nde.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-12-nde.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-12-nde.csv to the trimester 12-nde DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-11-ond.csv
# ene-2022-11-ond.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-11-ond.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-11-ond.csv to the trimester 11-ond DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-10-son.csv
# ene-2022-10-son.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-10-son.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-10-son.csv to the trimester 10-son DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-09-aso.csv
# ene-2022-09-aso.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-09-aso.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-09-aso.csv to the trimester 09-aso DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-08-jas.csv
# ene-2022-08-jas.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-08-jas.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-08-jas.csv to the trimester 08-jas DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-07-jja.csv
# ene-2022-07-jja.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-07-jja.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-07-jja.csv to the trimester 07-jja DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-06-mjj.csv
# ene-2022-06-mjj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-06-mjj.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-06-mjj.csv to the trimester 06-mjj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-05-amj.csv
# ene-2022-05-amj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-05-amj.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-05-amj.csv to the trimester 05-amj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-04-mam.csv
# ene-2022-04-mam.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-04-mam.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-04-mam.csv to the trimester 04-mam DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-03-fma.csv
# ene-2022-03-fma.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-03-fma.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-03-fma.csv to the trimester 03-fma DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-02-efm.csv
# ene-2022-02-efm.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-02-efm.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-02-efm.csv to the trimester 02-efm DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2022/csv/ene-2022-01-def.csv
# ene-2022-01-def.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2022-01-def.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2022-01-def.csv to the trimester 01-def DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-12-nde.csv
# ene-2021-12-nde.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-12-nde.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2021-12-nde.csv to the trimester 12-nde DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-11-ond.csv
# ene-2021-11-ond.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-11-ond.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-11-ond.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-11-ond.csv to the trimester 11-ond DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-10-son.csv
# ene-2021-10-son.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-10-son.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-10-son.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-10-son.csv to the trimester 10-son DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-09-aso.csv
# ene-2021-09-aso.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-09-aso.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-09-aso.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-09-aso.csv to the trimester 09-aso DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-08-jas.csv
# ene-2021-08-jas.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-08-jas.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-08-jas.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-08-jas.csv to the trimester 08-jas DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-07-jja.csv
# ene-2021-07-jja.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-07-jja.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-07-jja.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-07-jja.csv to the trimester 07-jja DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-06-mjj.csv
# ene-2021-06-mjj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-06-mjj.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-06-mjj.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-06-mjj.csv to the trimester 06-mjj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-05-amj.csv
# ene-2021-05-amj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-05-amj.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-05-amj.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-05-amj.csv to the trimester 05-amj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-04-mam.csv
# ene-2021-04-mam.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-04-mam.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-04-mam.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-04-mam.csv to the trimester 04-mam DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-03-fma.csv
# ene-2021-03-fma.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-03-fma.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-03-fma.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-03-fma.csv to the trimester 03-fma DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-02-efm.csv
# ene-2021-02-efm.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-02-efm.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-02-efm.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-02-efm.csv to the trimester 02-efm DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2021/csv/ene-2021-01-def.csv
# ene-2021-01-def.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-01-def.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2021-01-def.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2021-01-def.csv to the trimester 01-def DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-12-nde.csv
# ene-2020-12-nde.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-12-nde.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-12-nde.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2020-12-nde.csv to the trimester 12-nde DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-11-ond.csv
# ene-2020-11-ond.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-11-ond.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-11-ond.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2020-11-ond.csv to the trimester 11-ond DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-10-son.csv
# ene-2020-10-son.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-10-son.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-10-son.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2020-10-son.csv to the trimester 10-son DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-09-aso.csv
# ene-2020-09-aso.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-09-aso.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-09-aso.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2020-09-aso.csv to the trimester 09-aso DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-08-jas.csv
# ene-2020-08-jas.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-08-jas.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-08-jas.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2020-08-jas.csv to the trimester 08-jas DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-07-jja.csv
# ene-2020-07-jja.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-07-jja.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2020-07-jja.csv to the trimester 07-jja DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-06-mjj.csv
# ene-2020-06-mjj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-06-mjj.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2020-06-mjj.csv to the trimester 06-mjj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-05-amj.csv
# ene-2020-05-amj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-05-amj.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2020-05-amj.csv to the trimester 05-amj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-04-mam.csv
# ene-2020-04-mam.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-04-mam.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2020-04-mam.csv to the trimester 04-mam DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-03-fma.csv
# ene-2020-03-fma.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-03-fma.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2020-03-fma.csv to the trimester 03-fma DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-02-efm.csv
# ene-2020-02-efm.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-02-efm.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2020-02-efm.csv to the trimester 02-efm DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2020/csv/ene-2020-01-def.csv
# ene-2020-01-def.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2020-01-def.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2020-01-def.csv to the trimester 01-def DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-12-nde.csv
# ene-2019-12-nde.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-12-nde.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2019-12-nde.csv to the trimester 12-nde DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-11-ond.csv
# ene-2019-11-ond.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-11-ond.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-11-ond.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-11-ond.csv to the trimester 11-ond DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-10-son.csv
# ene-2019-10-son.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-10-son.csv: utf-8
# Successfully read file with encoding utf-8
# Added ene-2019-10-son.csv to the trimester 10-son DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-09-aso.csv
# ene-2019-09-aso.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-09-aso.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-09-aso.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-09-aso.csv to the trimester 09-aso DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-08-jas.csv
# ene-2019-08-jas.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-08-jas.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-08-jas.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-08-jas.csv to the trimester 08-jas DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-07-jja.csv
# ene-2019-07-jja.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-07-jja.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-07-jja.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-07-jja.csv to the trimester 07-jja DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-06-mjj.csv
# ene-2019-06-mjj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-06-mjj.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-06-mjj.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-06-mjj.csv to the trimester 06-mjj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-05-amj.csv
# ene-2019-05-amj.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-05-amj.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-05-amj.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-05-amj.csv to the trimester 05-amj DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-04-mam.csv
# ene-2019-04-mam.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-04-mam.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-04-mam.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-04-mam.csv to the trimester 04-mam DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-03-fma.csv
# ene-2019-03-fma.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-03-fma.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-03-fma.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-03-fma.csv to the trimester 03-fma DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-02-efm.csv
# ene-2019-02-efm.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-02-efm.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-02-efm.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-02-efm.csv to the trimester 02-efm DataFrame.
# Next https://www.ine.gob.cl/docs/default-source/ocupacion-y-desocupacion/bbdd/2019/csv/ene-2019-01-def.csv
# ene-2019-01-def.csv already exists. Skipping download.
# Detected encoding for /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-01-def.csv: utf-8
# Error reading CSV file /Users/ernestolaval/Documents/Github Repositories/data_chile/data/source/ine/empleo/ene-2019-01-def.csv with encoding utf-8, trying ISO-8859-1
# Successfully read file with encoding ISO-8859-1
# Added ene-2019-01-def.csv to the trimester 01-def DataFrame.

# %%
# List of columns to include
columns_to_include = [
    'ano_trimestre', 
    'mes_central', 
    'ano_encuesta',
    'mes_encuesta',
    
    'region',
    'edad',
    'tramo_edad',
    'sexo',
    'nivel',
    'termino_nivel',
    'cine',
    'nacionalidad',
    
    'b1',
    'b13_rev4cl_caenes', 
    'b14_rev4cl_caenes',
    'r_p_rev4cl_caenes',
    
    'habituales',
    'c10',
    'c11',
    
    'e4',
    
    'efectivas',
    
    'activ',
    'cae_general', 
    'cae_especifico', 
    'categoria_ocupacion',
    'ocup_form',
    'sector',
    'obe',
    'tpi',
    'id',
    'ftp',
    
    'fact_cal'
    
]  # Add other columns as needed

# %%
# Save each trimester DataFrame as a Parquet file
for trimester, df in trimester_data.items():
    # Select only the specified columns
    df = df[columns_to_include]
    
    processed_path = os.path.join(processed_dir, f"ene-{trimester}.parquet")
    df.to_parquet(processed_path)
    print(f"Merged DataFrame for trimester {trimester} saved to {processed_path}")
# Out:
# Merged DataFrame for trimester 04-mam saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-04-mam.parquet
# Merged DataFrame for trimester 03-fma saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-03-fma.parquet
# Merged DataFrame for trimester 02-efm saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-02-efm.parquet
# Merged DataFrame for trimester 01-def saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-01-def.parquet
# Merged DataFrame for trimester 12-nde saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-12-nde.parquet
# Merged DataFrame for trimester 11-ond saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-11-ond.parquet
# Merged DataFrame for trimester 10-son saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-10-son.parquet
# Merged DataFrame for trimester 09-aso saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-09-aso.parquet
# Merged DataFrame for trimester 08-jas saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-08-jas.parquet
# Merged DataFrame for trimester 07-jja saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-07-jja.parquet
# Merged DataFrame for trimester 06-mjj saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-06-mjj.parquet
# Merged DataFrame for trimester 05-amj saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-05-amj.parquet

# %% [markdown]
# ## Regenerar archivo para todos los meses / años con campos claves

# %%
import pandas as pd
import numpy as np
import glob

# Define the pattern to match all relevant Parquet files
file_pattern = processed_dir + '/ene-*-*.parquet'
print(file_pattern)

# Use glob to find all files matching the pattern
parquet_files = glob.glob(file_pattern)

# Initialize an empty list to hold the DataFrames
dfs = []

# Iterate over the list of files and read each one into a DataFrame
for file in parquet_files:
    df = pd.read_parquet(file)
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Display the first few rows of the combined DataFrame to check the data
print("Combined DataFrame:")
print(combined_df.head())

# Inspect the distribution of 'cae_especifico' values
print("Distribution of 'cae_especifico' values:")
print(combined_df['cae_especifico'].value_counts())

# Categorize 'Ocupacion' based on 'cae_especifico'
combined_df['Ocupacion'] = combined_df['cae_especifico'].apply(lambda x: 'Ocupados' if 1 <= x <= 7 else ('Desocupados' if 8 <= x <= 9 else 'Unknown'))

# Inspect the distribution of the new 'Ocupacion' column
print("Distribution of 'Ocupacion' values:")
print(combined_df['Ocupacion'].value_counts())

# Categorize 'Nacionalidad'
combined_df['Nacionalidad'] = combined_df['nacionalidad'].apply(lambda x: 'Chilena' if x == 152 else 'Extranjeros')

# Add 'edad_de_trabajar' column
combined_df['edad_de_trabajar'] = combined_df['edad'].apply(lambda x: 1 if x >= 15 else 0)

# Fill null values in the 'sexo' column
combined_df['sexo'] = combined_df['sexo'].fillna('Unknown').astype(str)

# Specify the key dimension fields to group by, including 'edad_de_trabajar' and 'sexo'
key_dimension_fields = [
    'ano_trimestre', 'mes_central', 'Ocupacion', 'Nacionalidad', 'categoria_ocupacion', 'b14_rev4cl_caenes', 'b1', 'ocup_form', 'sector', 'edad_de_trabajar', 'sexo'
]

# Fill null values in the key dimension fields with appropriate placeholders
combined_df['categoria_ocupacion'] = combined_df['categoria_ocupacion'].fillna(-1).astype(int)
combined_df['b14_rev4cl_caenes'] = combined_df['b14_rev4cl_caenes'].fillna(-1).astype(int)
combined_df['b1'] = combined_df['b1'].fillna(-1).astype(int)
combined_df['ocup_form'] = combined_df['ocup_form'].fillna(-1).astype(int)
combined_df['sector'] = combined_df['sector'].fillna(-1).astype(int)

# Aggregate the data by summing the 'fact_cal' metric
aggregated_df = combined_df.groupby(key_dimension_fields)['fact_cal'].sum().reset_index()

# Replace placeholders with np.nan after aggregation for integer columns
aggregated_df['categoria_ocupacion'] = aggregated_df['categoria_ocupacion'].replace(-1, np.nan).astype('Int64')
aggregated_df['b14_rev4cl_caenes'] = aggregated_df['b14_rev4cl_caenes'].replace(-1, np.nan).astype('Int64')
aggregated_df['b1'] = aggregated_df['b1'].replace(-1, np.nan).astype('Int64')
aggregated_df['ocup_form'] = aggregated_df['ocup_form'].replace(-1, np.nan).astype('Int64')
aggregated_df['sector'] = aggregated_df['sector'].replace(-1, np.nan).astype('Int64')

# Display the first few rows of the aggregated DataFrame to check the results
print("Aggregated DataFrame:")
print(aggregated_df.head())

# Save the aggregated DataFrame to a new Parquet file
output_parquet_file = processed_dir + '/ene_sintetica.parquet'
aggregated_df.to_parquet(output_parquet_file, index=False)

print(f"Aggregated data saved to {output_parquet_file}")
# Out:
# /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene-*-*.parquet
# Combined DataFrame:
#    ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  edad  \
# 0           2023            6          2023             5      13     9
# 1           2023            6          2023             5      13     4
# 2           2023            6          2023             5      13    38
# 3           2023            6          2023             5      13    43
# 4           2023            6          2023             5      13    29
#
#    tramo_edad  sexo  nivel  termino_nivel  ...  cae_general  cae_especifico  \
# 0         NaN     2      3              2  ...            0               0
# 1         NaN     2      1              1  ...            0               0
# 2         5.0     1      8              1  ...            1               1
# 3         6.0     2      8              1  ...            9              13
# 4         3.0     1      9              2  ...            9              15
#
#    categoria_ocupacion  ocup_form  sector  obe  tpi   id  ftp    fact_cal
# 0                    0        NaN     NaN  NaN  NaN  NaN  NaN  505.476482
# 1                    0        NaN     NaN  NaN  NaN  NaN  NaN  505.476482
# 2                    3        1.0     1.0  0.0  0.0  NaN  NaN  555.247762
# 3                    0        NaN     NaN  NaN  NaN  0.0  0.0  485.342199
# 4                    0        NaN     NaN  NaN  NaN  0.0  0.0  544.412115
#
# [5 rows x 32 columns]
# Distribution of 'cae_especifico' values:
# cae_especifico
# 1     2148638
# 0     1092177
# 15     501789
# 13     432466
# 19     280242
# 21     260772
# 17     245240
# 8      189243
# 5      154135
# 24     107145
# 12      77377
# 3       66414
# 27      62178
# 14      54810
# 23      47110
# 25      42775
# 6       41037
# 26      35422
# 22      25118
# 28      23416
# 7       22540
# 2       21729
# 9       21514
# 16      19729
# 20      18425
# 18      14409
# 10      11529
# 11       8451
# 4        3878
# Name: count, dtype: int64
# Distribution of 'Ocupacion' values:
# Ocupacion
# Unknown        3360580
# Ocupados       2458371
# Desocupados     210757
# Name: count, dtype: int64
# Aggregated DataFrame:
#    ano_trimestre  mes_central    Ocupacion Nacionalidad  categoria_ocupacion  \
# 0           2019            1  Desocupados      Chilena                    0
# 1           2019            1  Desocupados      Chilena                    0
# 2           2019            1  Desocupados  Extranjeros                    0
# 3           2019            1  Desocupados  Extranjeros                    0
# 4           2019            1     Ocupados      Chilena                    1
#
#    b14_rev4cl_caenes    b1  ocup_form  sector  edad_de_trabajar sexo  \
# 0               <NA>  <NA>       <NA>    <NA>                 1    1
# 1               <NA>  <NA>       <NA>    <NA>                 1    2
# 2               <NA>  <NA>       <NA>    <NA>                 1    1
# 3               <NA>  <NA>       <NA>    <NA>                 1    2
# 4                  1     1          1       1                 1    1
#
#         fact_cal
# 0  312462.342388
# 1  301712.082949
# 2   31003.353133
# 3   28821.156080
# 4    1689.884283
# Aggregated data saved to /Users/ernestolaval/Documents/Github Repositories/data_chile/data/processed/ine/empleo/ene_sintetica.parquet

# %%
trimester_data
# Out:
# defaultdict(pandas.core.frame.DataFrame,
#             {'04-mam':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2024            4          2024             3       3
#              1                2024            4          2024             3       3
#              2                2024            4          2024             3       3
#              3                2024            4          2024             3       3
#              4                2024            4          2024             3       3
#              ...               ...          ...           ...           ...     ...
#              572695           2019            4          2019             5       6
#              572696           2019            4          2019             5       6
#              572697           2019            4          2019             5       9
#              572698           2019            4          2019             5       9
#              572699           2019            4          2019             5      13
#
#                      provincia  r_p_c  estrato  tipo  conglomerado  ...  e14_mes  e14_ano  \
#              0              32   3202  3100210     1       17646.0  ...      NaN      NaN
#              1              32   3202  3100210     1       17646.0  ...      NaN      NaN
#              2              32   3202  3100210     1       17646.0  ...      NaN      NaN
#              3              32   3202  3100210     1       17646.0  ...      NaN      NaN
#              4              32   3202  3100210     1       17646.0  ...      NaN      NaN
#              ...           ...    ...      ...   ...           ...  ...      ...      ...
#              572695         61   6109     6039     3           NaN  ...      5.0   2019.0
#              572696         61   6109     6039     3           NaN  ...      NaN      NaN
#              572697         91   9101     9031     1           NaN  ...      NaN      NaN
#              572698         91   9101     9031     1           NaN  ...      NaN      NaN
#              572699        136  13605    13442     2           NaN  ...      NaN      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e17  e18_rev4cl_caenes   e19  \
#              0             NaN       NaN         NaN  NaN                NaN   NaN
#              1             NaN       NaN         NaN  NaN                NaN   NaN
#              2             NaN       NaN         NaN  NaN                NaN   NaN
#              3             NaN       NaN         NaN  NaN                NaN   NaN
#              4             NaN       NaN         NaN  NaN                NaN   NaN
#              ...           ...       ...         ...  ...                ...   ...
#              572695        3.0       0.0         7.0  3.0                3.0  12.0
#              572696        NaN       NaN         NaN  NaN                NaN   NaN
#              572697        NaN       NaN         NaN  NaN                NaN   NaN
#              572698        NaN       NaN         NaN  NaN                NaN   NaN
#              572699        NaN       NaN         NaN  NaN                NaN   NaN
#
#                      e19_otro              fact
#              0            NaN               NaN
#              1            NaN               NaN
#              2            NaN               NaN
#              3            NaN               NaN
#              4            NaN               NaN
#              ...          ...               ...
#              572695       NaN  132,466568284513
#              572696       NaN  116,514036087476
#              572697       NaN  114,851310938407
#              572698       NaN  111,463654665114
#              572699       NaN  185,712226143229
#
#              [572700 rows x 219 columns],
#              '03-fma':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2024            3          2024             2       6
#              1                2024            3          2024             2       6
#              2                2024            3          2024             2       6
#              3                2024            3          2024             2       6
#              4                2024            3          2024             2       6
#              ...               ...          ...           ...           ...     ...
#              572279           2019            3          2019             4      13
#              572280           2019            3          2019             4      13
#              572281           2019            3          2019             4      13
#              572282           2019            3          2019             4      13
#              572283           2019            3          2019             4      13
#
#                      provincia  r_p_c  estrato  tipo  conglomerado  ...  e14_mes  e14_ano  \
#              0              61   6101  6100112     1       10262.0  ...      NaN      NaN
#              1              61   6101  6100112     1       10262.0  ...      NaN      NaN
#              2              61   6101  6100112     1       10262.0  ...      NaN      NaN
#              3              61   6101  6100112     1       10262.0  ...      NaN      NaN
#              4              61   6101  6100112     1       10262.0  ...      NaN      NaN
#              ...           ...    ...      ...   ...           ...  ...      ...      ...
#              572279        131  13123    13291     1           NaN  ...      NaN      NaN
#              572280        134  13401    13381     1           NaN  ...      NaN      NaN
#              572281        134  13401    13381     1           NaN  ...      NaN      NaN
#              572282        134  13401    13381     1           NaN  ...      NaN      NaN
#              572283        135  13501    13411     1           NaN  ...      NaN      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e17  e18_rev4cl_caenes  e19  \
#              0             NaN       NaN         NaN  NaN                NaN  NaN
#              1             NaN       NaN         NaN  NaN                NaN  NaN
#              2             NaN       NaN         NaN  NaN                NaN  NaN
#              3             NaN       NaN         NaN  NaN                NaN  NaN
#              4             NaN       NaN         NaN  NaN                NaN  NaN
#              ...           ...       ...         ...  ...                ...  ...
#              572279        NaN       NaN         NaN  NaN                NaN  NaN
#              572280        NaN       NaN         NaN  NaN                NaN  NaN
#              572281        NaN       NaN         NaN  NaN                NaN  NaN
#              572282        NaN       NaN         NaN  NaN                NaN  NaN
#              572283        NaN       NaN         NaN  NaN                NaN  NaN
#
#                      e19_otro              fact
#              0            NaN               NaN
#              1            NaN               NaN
#              2            NaN               NaN
#              3            NaN               NaN
#              4            NaN               NaN
#              ...          ...               ...
#              572279       NaN  300,225467744978
#              572280       NaN  57,5219911657482
#              572281       NaN  71,6613536184454
#              572282       NaN  64,2587637773738
#              572283       NaN  66,0094699155576
#
#              [572284 rows x 219 columns],
#              '02-efm':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2024            2          2024             1      15
#              1                2024            2          2024             1      15
#              2                2024            2          2024             1      15
#              3                2024            2          2024             1      15
#              4                2024            2          2024             1      15
#              ...               ...          ...           ...           ...     ...
#              566334           2019            2          2019             3       9
#              566335           2019            2          2019             3       9
#              566336           2019            2          2019             3       9
#              566337           2019            2          2019             3       9
#              566338           2019            2          2019             3       8
#
#                      provincia  r_p_c   estrato  tipo  conglomerado  ...  e14_ano  \
#              0             151  15101  15000012     1       34468.0  ...      NaN
#              1             151  15101  15000012     1       34468.0  ...      NaN
#              2             151  15101  15000012     1       34468.0  ...      NaN
#              3             151  15101  15000012     1       34468.0  ...      NaN
#              4             151  15101  15000012     1       34468.0  ...      NaN
#              ...           ...    ...       ...   ...           ...  ...      ...
#              566334         92   9203      9012     2           NaN  ...      NaN
#              566335         92   9203      9012     2           NaN  ...      NaN
#              566336         91   9101      9031     1           NaN  ...      NaN
#              566337         91   9101      9031     1           NaN  ...      NaN
#              566338         81   8107      8061     1           NaN  ...      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e16_ciuo88  e17  e18_rev4cl_caenes  \
#              0             NaN       NaN         NaN         NaN  NaN                NaN
#              1             NaN       NaN         NaN         NaN  NaN                NaN
#              2             NaN       NaN         NaN         NaN  NaN                NaN
#              3             NaN       NaN         NaN         NaN  NaN                NaN
#              4             NaN       NaN         NaN         NaN  NaN                NaN
#              ...           ...       ...         ...         ...  ...                ...
#              566334        NaN       NaN         NaN         NaN  NaN                NaN
#              566335        NaN       NaN         NaN         NaN  NaN                NaN
#              566336        NaN       NaN         NaN         NaN  NaN                NaN
#              566337        NaN       NaN         NaN         NaN  NaN                NaN
#              566338        NaN       NaN         NaN         NaN  NaN                NaN
#
#                      e19  e19_otro              fact
#              0       NaN       NaN               NaN
#              1       NaN       NaN               NaN
#              2       NaN       NaN               NaN
#              3       NaN       NaN               NaN
#              4       NaN       NaN               NaN
#              ...     ...       ...               ...
#              566334  NaN       NaN  128,204956495111
#              566335  NaN       NaN  134,461596659983
#              566336  NaN       NaN  176,684869950668
#              566337  NaN       NaN  176,684869950668
#              566338  NaN       NaN  254,351249326149
#
#              [566339 rows x 221 columns],
#              '01-def':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2024            1          2023            12       6
#              1                2024            1          2023            12       6
#              2                2024            1          2023            12       6
#              3                2024            1          2023            12       6
#              4                2024            1          2023            12       6
#              ...               ...          ...           ...           ...     ...
#              566378           2019            1          2019             2      13
#              566379           2019            1          2019             2      13
#              566380           2019            1          2019             2      13
#              566381           2019            1          2019             2       6
#              566382           2019            1          2019             2       6
#
#                      provincia  r_p_c  estrato  tipo  conglomerado  ...  e14_ano  \
#              0              61   6117  6100310     1       43135.0  ...      NaN
#              1              61   6117  6100310     1       43135.0  ...      NaN
#              2              61   6117  6100310     1       43135.0  ...      NaN
#              3              61   6117  6100310     1       43135.0  ...      NaN
#              4              61   6117  6100310     1       43135.0  ...      NaN
#              ...           ...    ...      ...   ...           ...  ...      ...
#              566378        134  13401    13381     1           NaN  ...      NaN
#              566379        136  13601    13459     3           NaN  ...   1998.0
#              566380        136  13601    13459     3           NaN  ...   2009.0
#              566381         63   6301     6081     1           NaN  ...      NaN
#              566382         63   6301     6081     1           NaN  ...      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e16_ciuo88  e17  e18_rev4cl_caenes  \
#              0             NaN       NaN         NaN         NaN  NaN                NaN
#              1             NaN       NaN         NaN         NaN  NaN                NaN
#              2             NaN       NaN         NaN         NaN  NaN                NaN
#              3             NaN       NaN         NaN         NaN  NaN                NaN
#              4             NaN       NaN         NaN         NaN  NaN                NaN
#              ...           ...       ...         ...         ...  ...                ...
#              566378        NaN       NaN         NaN         NaN  NaN                NaN
#              566379       99.0      30.0         1.0         1.0  3.0                7.0
#              566380       99.0      10.0         3.0         9.0  2.0                7.0
#              566381        NaN       NaN         NaN         NaN  NaN                NaN
#              566382        NaN       NaN         NaN         NaN  NaN                NaN
#
#                      e19  e19_otro              fact
#              0       NaN       NaN               NaN
#              1       NaN       NaN               NaN
#              2       NaN       NaN               NaN
#              3       NaN       NaN               NaN
#              4       NaN       NaN               NaN
#              ...     ...       ...               ...
#              566378  NaN       NaN   74,622981294115
#              566379  4.0       NaN  300,281634479572
#              566380  4.0       NaN  279,072208432079
#              566381  NaN       NaN  20,9082124736009
#              566382  NaN       NaN  16,5710245694705
#
#              [566383 rows x 221 columns],
#              '12-nde':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2023           12          2023            11       8
#              1                2023           12          2023            11      10
#              2                2023           12          2023            11      10
#              3                2023           12          2023            11      10
#              4                2023           12          2023            11      10
#              ...               ...          ...           ...           ...     ...
#              459620           2019           12          2020             1       9
#              459621           2019           12          2020             1       9
#              459622           2019           12          2020             1       5
#              459623           2019           12          2020             1       5
#              459624           2019           12          2020             1       5
#
#                      provincia  r_p_c   estrato  tipo  conglomerado  ...  i13_6  i13_7  \
#              0              81   8102   8100111     1         29123  ...    NaN    NaN
#              1             101  10101  10100113     1         10102  ...    NaN    NaN
#              2             101  10101  10100113     1         10102  ...    NaN    NaN
#              3             101  10101  10100112     1         24674  ...    NaN    NaN
#              4             101  10101  10100112     1         24674  ...    NaN    NaN
#              ...           ...    ...       ...   ...           ...  ...    ...    ...
#              459620         92   9201      9061     1  920100100292  ...    NaN    NaN
#              459621         92   9201      9061     1  920100100292  ...    NaN    NaN
#              459622         55   5501      5071     1  550100100506  ...    NaN    NaN
#              459623         55   5501      5071     1  550100100506  ...    NaN    NaN
#              459624         55   5501      5071     1  550100100506  ...    NaN    NaN
#
#                      i13_8  i13_9  i13_10  i13_11  i13_88  i13_99  i13_total  b11
#              0         NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#              1         NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#              2         NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#              3         NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#              4         NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#              ...       ...    ...     ...     ...     ...     ...        ...  ...
#              459620    NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#              459621    NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#              459622    NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#              459623    NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#              459624    NaN    NaN     NaN     NaN     NaN     NaN        NaN  NaN
#
#              [459625 rows x 204 columns],
#              '11-ond':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2023           11          2023            10       4
#              1                2023           11          2023            10       4
#              2                2023           11          2023            10       4
#              3                2023           11          2023            10       4
#              4                2023           11          2023            10       4
#              ...               ...          ...           ...           ...     ...
#              459704           2019           11          2019            12       4
#              459705           2019           11          2019            12      13
#              459706           2019           11          2019            12      11
#              459707           2019           11          2019            12      11
#              459708           2019           11          2019            12      11
#
#                      provincia  r_p_c  estrato  tipo  conglomerado  ...  e14_mes  e14_ano  \
#              0              42   4204  4200120     3       17239.0  ...      NaN      NaN
#              1              42   4204  4200120     3       17239.0  ...      NaN      NaN
#              2              42   4204  4200120     3       17239.0  ...      NaN      NaN
#              3              42   4204  4200120     3       17239.0  ...      NaN      NaN
#              4              42   4204  4200120     3       17239.0  ...      NaN      NaN
#              ...           ...    ...      ...   ...           ...  ...      ...      ...
#              459704         43   4301     4051     1           NaN  ...      NaN      NaN
#              459705        136  13605    13442     2           NaN  ...      NaN      NaN
#              459706        112  11201    11041     1           NaN  ...      NaN      NaN
#              459707        112  11201    11041     1           NaN  ...      NaN      NaN
#              459708        112  11201    11041     1           NaN  ...      NaN      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e17  e18_rev4cl_caenes  e19  \
#              0             NaN       NaN         NaN  NaN                NaN  NaN
#              1             NaN       NaN         NaN  NaN                NaN  NaN
#              2             NaN       NaN         NaN  NaN                NaN  NaN
#              3             NaN       NaN         NaN  NaN                NaN  NaN
#              4             NaN       NaN         NaN  NaN                NaN  NaN
#              ...           ...       ...         ...  ...                ...  ...
#              459704        0.0       0.0         NaN  NaN                NaN  NaN
#              459705        NaN       NaN         NaN  NaN                NaN  NaN
#              459706        NaN       NaN         NaN  NaN                NaN  NaN
#              459707        NaN       NaN         NaN  NaN                NaN  NaN
#              459708        NaN       NaN         NaN  NaN                NaN  NaN
#
#                      e19_otro              fact
#              0            NaN               NaN
#              1            NaN               NaN
#              2            NaN               NaN
#              3            NaN               NaN
#              4            NaN               NaN
#              ...          ...               ...
#              459704       NaN  143,946799075997
#              459705       NaN  198,774642167263
#              459706       NaN  17,1288954094164
#              459707       NaN  20,4257314372068
#              459708       NaN  20,4257314372068
#
#              [459709 rows x 219 columns],
#              '10-son':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2023           10          2023             9      10
#              1                2023           10          2023             9      10
#              2                2023           10          2023             9      10
#              3                2023           10          2023             9      10
#              4                2023           10          2023             9      10
#              ...               ...          ...           ...           ...     ...
#              463500           2019           10          2019            11       5
#              463501           2019           10          2019            11       5
#              463502           2019           10          2019            11      15
#              463503           2019           10          2019            11      15
#              463504           2019           10          2019            11      15
#
#                      provincia  r_p_c   estrato  tipo  conglomerado  ...  e14_mes  e14_ano  \
#              0             103  10301  10200111     1       28503.0  ...      NaN      NaN
#              1             103  10301  10200111     1       28503.0  ...      NaN      NaN
#              2             103  10301  10200111     1       28503.0  ...      NaN      NaN
#              3             103  10301  10200111     1       28503.0  ...      NaN      NaN
#              4             103  10301  10200111     1       28503.0  ...      NaN      NaN
#              ...           ...    ...       ...   ...           ...  ...      ...      ...
#              463500         58   5801      5121     1           NaN  ...      NaN      NaN
#              463501         58   5801      5121     1           NaN  ...      NaN      NaN
#              463502        151  15101     15011     1           NaN  ...      NaN      NaN
#              463503        151  15101     15011     1           NaN  ...      9.0   2019.0
#              463504        151  15101     15011     1           NaN  ...      NaN      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e17  e18_rev4cl_caenes  e19  \
#              0             NaN       NaN         NaN  NaN                NaN  NaN
#              1             NaN       NaN         NaN  NaN                NaN  NaN
#              2             NaN       NaN         NaN  NaN                NaN  NaN
#              3             NaN       NaN         NaN  NaN                NaN  NaN
#              4             NaN       NaN         NaN  NaN                NaN  NaN
#              ...           ...       ...         ...  ...                ...  ...
#              463500        NaN       NaN         NaN  NaN                NaN  NaN
#              463501        NaN       NaN         NaN  NaN                NaN  NaN
#              463502        NaN       NaN         NaN  NaN                NaN  NaN
#              463503        9.0       1.0         7.0  3.0                3.0  7.0
#              463504        0.0       0.0         NaN  NaN                NaN  NaN
#
#                      e19_otro              fact
#              0            NaN               NaN
#              1            NaN               NaN
#              2            NaN               NaN
#              3            NaN               NaN
#              4            NaN               NaN
#              ...          ...               ...
#              463500       NaN  137,367436444231
#              463501       NaN  113,901775970345
#              463502       NaN  41,8586051275871
#              463503       NaN  36,4791613434709
#              463504       NaN  41,8586051275871
#
#              [463505 rows x 219 columns],
#              '09-aso':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2023            9          2023             8      16
#              1                2023            9          2023             8      16
#              2                2023            9          2023             8      16
#              3                2023            9          2023             8      16
#              4                2023            9          2023             8      16
#              ...               ...          ...           ...           ...     ...
#              468171           2019            9          2019            10      13
#              468172           2019            9          2019            10      13
#              468173           2019            9          2019            10      13
#              468174           2019            9          2019            10      13
#              468175           2019            9          2019            10      13
#
#                      provincia  r_p_c   estrato  tipo  conglomerado  ...  e14_mes  e14_ano  \
#              0             161  16108  16100210     1       42811.0  ...      NaN      NaN
#              1             161  16108  16100210     1       42811.0  ...      NaN      NaN
#              2             161  16108  16100210     1       42811.0  ...      NaN      NaN
#              3             161  16108  16100210     1       42811.0  ...      NaN      NaN
#              4             161  16108  16100210     1       42811.0  ...      NaN      NaN
#              ...           ...    ...       ...   ...           ...  ...      ...      ...
#              468171        131  13132     13311     1           NaN  ...      NaN      NaN
#              468172        131  13132     13311     1           NaN  ...     10.0   2018.0
#              468173        131  13125     13071     1           NaN  ...      NaN      NaN
#              468174        131  13125     13071     1           NaN  ...      3.0   2016.0
#              468175        131  13125     13071     1           NaN  ...      NaN      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e17  e18_rev4cl_caenes   e19  \
#              0             NaN       NaN         NaN  NaN                NaN   NaN
#              1             NaN       NaN         NaN  NaN                NaN   NaN
#              2             NaN       NaN         NaN  NaN                NaN   NaN
#              3             NaN       NaN         NaN  NaN                NaN   NaN
#              4             NaN       NaN         NaN  NaN                NaN   NaN
#              ...           ...       ...         ...  ...                ...   ...
#              468171        NaN       NaN         NaN  NaN                NaN   NaN
#              468172        0.0       4.0         2.0  4.0               15.0   1.0
#              468173        NaN       NaN         NaN  NaN                NaN   NaN
#              468174        4.0       0.0         9.0  3.0                7.0  10.0
#              468175        NaN       NaN         NaN  NaN                NaN   NaN
#
#                      e19_otro              fact
#              0            NaN               NaN
#              1            NaN               NaN
#              2            NaN               NaN
#              3            NaN               NaN
#              4            NaN               NaN
#              ...          ...               ...
#              468171       NaN  154,106552737274
#              468172       NaN  179,202082659007
#              468173       NaN  457,274164073204
#              468174       NaN   489,81741097692
#              468175       NaN   592,16221989953
#
#              [468176 rows x 219 columns],
#              '08-jas':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2023            8          2023             7       5
#              1                2023            8          2023             7       5
#              2                2023            8          2023             7       5
#              3                2023            8          2023             7       5
#              4                2023            8          2023             7       5
#              ...               ...          ...           ...           ...     ...
#              476821           2019            8          2019             9      13
#              476822           2019            8          2019             9       1
#              476823           2019            8          2019             9      16
#              476824           2019            8          2019             9      16
#              476825           2019            8          2019             9      13
#
#                      provincia  r_p_c  estrato  tipo  conglomerado  ...  e14_mes  e14_ano  \
#              0              55   5502  5500120     3       13969.0  ...      NaN      NaN
#              1              55   5502  5500120     3       13969.0  ...      NaN      NaN
#              2              55   5502  5500120     3       13969.0  ...      NaN      NaN
#              3              55   5502  5500120     3       13969.0  ...      NaN      NaN
#              4              55   5502  5500120     3       13969.0  ...      NaN      NaN
#              ...           ...    ...      ...   ...           ...  ...      ...      ...
#              476821        135  13501    13439     3           NaN  ...      NaN      NaN
#              476822         11   1101     1021     1           NaN  ...      NaN      NaN
#              476823        161  16103    16161     1           NaN  ...      NaN      NaN
#              476824        161  16103    16161     1           NaN  ...      NaN      NaN
#              476825        131  13114    13301     1           NaN  ...      NaN      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e17  e18_rev4cl_caenes  e19  \
#              0             NaN       NaN         NaN  NaN                NaN  NaN
#              1             NaN       NaN         NaN  NaN                NaN  NaN
#              2             NaN       NaN         NaN  NaN                NaN  NaN
#              3             NaN       NaN         NaN  NaN                NaN  NaN
#              4             NaN       NaN         NaN  NaN                NaN  NaN
#              ...           ...       ...         ...  ...                ...  ...
#              476821        NaN       NaN         NaN  NaN                NaN  NaN
#              476822        NaN       NaN         NaN  NaN                NaN  NaN
#              476823        NaN       NaN         NaN  NaN                NaN  NaN
#              476824        NaN       NaN         NaN  NaN                NaN  NaN
#              476825        NaN       NaN         NaN  NaN                NaN  NaN
#
#                      e19_otro              fact
#              0            NaN               NaN
#              1            NaN               NaN
#              2            NaN               NaN
#              3            NaN               NaN
#              4            NaN               NaN
#              ...          ...               ...
#              476821       NaN  426,716882350306
#              476822       NaN  29,1513425171779
#              476823       NaN  72,2465014732313
#              476824       NaN  71,0641667730946
#              476825       NaN   710,07410971061
#
#              [476826 rows x 219 columns],
#              '07-jja':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2023            7          2023             6       8
#              1                2023            7          2023             6       8
#              2                2023            7          2023             6       8
#              3                2023            7          2023             6       8
#              4                2023            7          2023             6       8
#              ...               ...          ...           ...           ...     ...
#              476982           2019            7          2019             8       8
#              476983           2019            7          2019             8       8
#              476984           2019            7          2019             8       8
#              476985           2019            7          2019             8       8
#              476986           2019            7          2019             8       8
#
#                      provincia  r_p_c  estrato  tipo  conglomerado  ...  e14_mes  e14_ano  \
#              0              83   8305  8300320     3       32455.0  ...      NaN      NaN
#              1              83   8305  8300320     3       32455.0  ...      NaN      NaN
#              2              83   8305  8300320     3       32455.0  ...      NaN      NaN
#              3              83   8305  8300320     3       32455.0  ...      NaN      NaN
#              4              83   8305  8300320     3       32455.0  ...      NaN      NaN
#              ...           ...    ...      ...   ...           ...  ...      ...      ...
#              476982         83   8301     8131     1           NaN  ...      NaN      NaN
#              476983         83   8306     8159     3           NaN  ...     99.0   1995.0
#              476984         83   8306     8159     3           NaN  ...      NaN      NaN
#              476985         81   8106     8071     1           NaN  ...      NaN      NaN
#              476986         81   8106     8071     1           NaN  ...     99.0   2003.0
#
#                      e15_meses  e15_anos  e16_ciuo08  e17  e18_rev4cl_caenes   e19  \
#              0             NaN       NaN         NaN  NaN                NaN   NaN
#              1             NaN       NaN         NaN  NaN                NaN   NaN
#              2             NaN       NaN         NaN  NaN                NaN   NaN
#              3             NaN       NaN         NaN  NaN                NaN   NaN
#              4             NaN       NaN         NaN  NaN                NaN   NaN
#              ...           ...       ...         ...  ...                ...   ...
#              476982        NaN       NaN         NaN  NaN                NaN   NaN
#              476983        0.0      10.0         9.0  5.0               20.0  11.0
#              476984        NaN       NaN         NaN  NaN                NaN   NaN
#              476985        NaN       NaN         NaN  NaN                NaN   NaN
#              476986        0.0       6.0         9.0  6.0               20.0  11.0
#
#                      e19_otro              fact
#              0            NaN               NaN
#              1            NaN               NaN
#              2            NaN               NaN
#              3            NaN               NaN
#              4            NaN               NaN
#              ...          ...               ...
#              476982       NaN  97,5402551251332
#              476983       NaN  207,180663478828
#              476984       NaN  188,603579452627
#              476985       NaN  32,2509719729724
#              476986       NaN  32,2509719729724
#
#              [476987 rows x 219 columns],
#              '06-mjj':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2023            6          2023             5      13
#              1                2023            6          2023             5      13
#              2                2023            6          2023             5      13
#              3                2023            6          2023             5      13
#              4                2023            6          2023             5      13
#              ...               ...          ...           ...           ...     ...
#              474396           2019            6          2019             7      13
#              474397           2019            6          2019             7      13
#              474398           2019            6          2019             7      13
#              474399           2019            6          2019             7      13
#              474400           2019            6          2019             7      13
#
#                      provincia  r_p_c   estrato  tipo  conglomerado  ...  e14_mes  e14_ano  \
#              0             132  13201  13200113     1       23038.0  ...      NaN      NaN
#              1             132  13201  13200113     1       23038.0  ...      NaN      NaN
#              2             132  13201  13200113     1       23038.0  ...      NaN      NaN
#              3             132  13201  13200113     1       23038.0  ...      NaN      NaN
#              4             132  13201  13200113     1       23038.0  ...      NaN      NaN
#              ...           ...    ...       ...   ...           ...  ...      ...      ...
#              474396        135  13501     13411     1           NaN  ...      NaN      NaN
#              474397        135  13501     13411     1           NaN  ...      NaN      NaN
#              474398        135  13501     13411     1           NaN  ...      NaN      NaN
#              474399        135  13501     13411     1           NaN  ...      NaN      NaN
#              474400        135  13501     13411     1           NaN  ...      NaN      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e17  e18_rev4cl_caenes  e19  \
#              0             NaN       NaN         NaN  NaN                NaN  NaN
#              1             NaN       NaN         NaN  NaN                NaN  NaN
#              2             NaN       NaN         NaN  NaN                NaN  NaN
#              3             NaN       NaN         NaN  NaN                NaN  NaN
#              4             NaN       NaN         NaN  NaN                NaN  NaN
#              ...           ...       ...         ...  ...                ...  ...
#              474396        NaN       NaN         NaN  NaN                NaN  NaN
#              474397        NaN       NaN         NaN  NaN                NaN  NaN
#              474398        NaN       NaN         NaN  NaN                NaN  NaN
#              474399        NaN       NaN         NaN  NaN                NaN  NaN
#              474400        NaN       NaN         NaN  NaN                NaN  NaN
#
#                      e19_otro              fact
#              0            NaN               NaN
#              1            NaN               NaN
#              2            NaN               NaN
#              3            NaN               NaN
#              4            NaN               NaN
#              ...          ...               ...
#              474396       NaN  15,0970044683997
#              474397       NaN  11,0809331797814
#              474398       NaN  15,0297070507727
#              474399       NaN  15,0297070507727
#              474400       NaN   11,611655925805
#
#              [474401 rows x 219 columns],
#              '05-amj':         ano_trimestre  mes_central  ano_encuesta  mes_encuesta  region  \
#              0                2023            5          2023             4      13
#              1                2023            5          2023             4      13
#              2                2023            5          2023             4      13
#              3                2023            5          2023             4      13
#              4                2023            5          2023             4      13
#              ...               ...          ...           ...           ...     ...
#              472768           2019            5          2019             6       2
#              472769           2019            5          2019             6       4
#              472770           2019            5          2019             6       4
#              472771           2019            5          2019             6       8
#              472772           2019            5          2019             6       8
#
#                      provincia  r_p_c   estrato  tipo  conglomerado  ...  e14_mes  e14_ano  \
#              0             133  13301  13300111     1       13160.0  ...      NaN      NaN
#              1             133  13301  13300111     1       13160.0  ...      NaN      NaN
#              2             133  13301  13300111     1       13160.0  ...      NaN      NaN
#              3             133  13301  13300111     1       13160.0  ...      NaN      NaN
#              4             133  13301  13300111     1       13160.0  ...      NaN      NaN
#              ...           ...    ...       ...   ...           ...  ...      ...      ...
#              472768         21   2101      2011     1           NaN  ...      NaN      NaN
#              472769         43   4303      4079     3           NaN  ...      6.0   2019.0
#              472770         43   4303      4079     3           NaN  ...      NaN      NaN
#              472771         81   8101      8041     1           NaN  ...      NaN      NaN
#              472772         81   8101      8041     1           NaN  ...      NaN      NaN
#
#                      e15_meses  e15_anos  e16_ciuo08  e17  e18_rev4cl_caenes   e19  \
#              0             NaN       NaN         NaN  NaN                NaN   NaN
#              1             NaN       NaN         NaN  NaN                NaN   NaN
#              2             NaN       NaN         NaN  NaN                NaN   NaN
#              3             NaN       NaN         NaN  NaN                NaN   NaN
#              4             NaN       NaN         NaN  NaN                NaN   NaN
#              ...           ...       ...         ...  ...                ...   ...
#              472768        NaN       NaN         NaN  NaN                NaN   NaN
#              472769        0.0      57.0         7.0  2.0                6.0  12.0
#              472770        NaN       NaN         NaN  NaN                NaN   NaN
#              472771        NaN       NaN         NaN  NaN                NaN   NaN
#              472772        NaN       NaN         NaN  NaN                NaN   NaN
#
#                      e19_otro              fact
#              0            NaN               NaN
#              1            NaN               NaN
#              2            NaN               NaN
#              3            NaN               NaN
#              4            NaN               NaN
#              ...          ...               ...
#              472768       NaN  138,715938272777
#              472769       NaN  80,6325342026427
#              472770       NaN  66,8546559985655
#              472771       NaN  132,438310322336
#              472772       NaN  170,866145757455
#
#              [472773 rows x 219 columns]})

# %%
# Initialize an empty DataFrame to store the IDs
all_ids = pd.DataFrame()

# Loop through each DataFrame in the dictionary
for key, df in trimester_data.items():
    # Extract the relevant columns
    ids = df[['id_identificacion', 'idrph']].copy()
    
    # Add a column for the source key to track where the IDs came from
    ids['source_key'] = key
    
    # Append to the all_ids DataFrame
    all_ids = pd.concat([all_ids, ids])

# Check for duplicate ids
duplicates = all_ids[all_ids.duplicated(subset=['id_identificacion', 'idrph'], keep=False)]

# %%
# Check for duplicate ids
duplicates = all_ids[all_ids.duplicated(subset=['id_identificacion', 'idrph'], keep=False)]

if not duplicates.empty:
    print("Duplicate IDs found:")
    print(duplicates)
else:
    print("No duplicate IDs found.")
# Out:
# Duplicate IDs found:
#         id_identificacion        idrph source_key
# 0                142976.0  11157359096     04-mam
# 1                142976.0  15665751893     04-mam
# 2                142977.0   5225326835     04-mam
# 3                142977.0  17833577210     04-mam
# 4                142977.0   4027374380     04-mam
# ...                   ...          ...        ...
# 472768           267851.0      1392037     05-amj
# 472769           297633.0      1392048     05-amj
# 472770           297633.0      1392050     05-amj
# 472771           289011.0      1392052     05-amj
# 472772           289011.0      1392053     05-amj
#
# [5978606 rows x 3 columns]

# %%
if not duplicates.empty:
    print("Duplicate IDs found:")
    
    # Group by ID and count the number of unique source_keys for each ID
    duplicates_summary = duplicates.groupby(['id_identificacion', 'idrph']).agg({
        'source_key': pd.Series.nunique
    }).reset_index()
    
    # Rename the columns for clarity
    duplicates_summary.columns = ['id_identificacion', 'idrph', 'trimesters_count']
    
    # Get the count of IDs that are duplicated in multiple trimesters
    summary_count = duplicates_summary['trimesters_count'].value_counts().reset_index()
    summary_count.columns = ['trimesters_count', 'id_count']
    
    print("Summary of duplicate IDs across trimesters:")
    print(summary_count)
else:
    print("No duplicate IDs found.")
# Out:
# Duplicate IDs found:
# Summary of duplicate IDs across trimesters:
#     trimesters_count  id_count
# 0                  3    312347
# 1                 12    141989
# 2                  6     98082
# 3                  9     95492
# 4                  2     60522
# 5                 11     32808
# 6                  4     25962
# 7                  5     24711
# 8                  7     22377
# 9                  8     21348
# 10                10     10062

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement ace_tools (from versions: none)
# ERROR: No matching distribution found for ace_tools
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = trimester_data['03-fma']

# %%
df2 = trimester_data['04-mam']

# %%
df1 = df1[df1['ano_trimestre'] == 2024]
df2 = df2[df2['ano_trimestre'] == 2024]

# %%
    # Extract the overlapping months
    overlapping_months = set(df1['mes_encuesta']).intersection(set(df2['mes_encuesta']))

# %%
overlapping_months
# Out:
# {3, 4}

# %%
    df1_overlap = df1[df1['mes_encuesta'].isin(overlapping_months)]
    df2_overlap = df2[df2['mes_encuesta'].isin(overlapping_months)]

# %%
# Compare the IDs for these overlapping months
common_ids_df1 = df1_overlap['id_identificacion'].unique()
common_ids_df2 = df2_overlap['id_identificacion'].unique()

# %%
common_ids = set(common_ids_df1).intersection(set(common_ids_df2))

# %%
print(f"Overlapping months between  and for the year {2024}: {overlapping_months}")
print(f"Number of common IDs in overlapping months: {len(common_ids)}")
print(f"Common IDs: {common_ids}")
# Out:
# Overlapping months between  and for the year 2024: {3, 4}
# Number of common IDs in overlapping months: 24195
# Common IDs: {142976, 142977, 142978, 142979, 142980, 142981, 142982, 142984, 142985, 142986, 142987, 142989, 142992, 142994, 142995, 142996, 142997, 142998, 142999, 143000, 143003, 143005, 143006, 143008, 143009, 143011, 143012, 143013, 143015, 143018, 143021, 143022, 143023, 143024, 143025, 143026, 143027, 143028, 143029, 143030, 143031, 143032, 143033, 143034, 143035, 143037, 143038, 143039, 143041, 143042, 143043, 143046, 143047, 143048, 143049, 143051, 143052, 143055, 143057, 143058, 143061, 143062, 143063, 143064, 143065, 143066, 143067, 143068, 143070, 143071, 143072, 143073, 143074, 143076, 143079, 143080, 143081, 143082, 143083, 143084, 143085, 143086, 143087, 143088, 143089, 143090, 143091, 143092, 143095, 143096, 143098, 143099, 143101, 143102, 143103, 143105, 143106, 143110, 143111, 143112, 143113, 143114, 143115, 143116, 143117, 143118, 143119, 143121, 143123, 143124, 143125, 143126, 143127, 143128, 143129, 143131, 143132, 143133, 143134, 143137, 143139, 143142, 143150, 143153, 143156, 143157, 143159, 143161, 143162, 143164, 143165, 143166, 143167, 143168, 143170, 143171, 143172, 143174, 143175, 143176, 143177, 143179, 143180, 143182, 143183, 143184, 143185, 143186, 143187, 143188, 143189, 143191, 143192, 143195, 143196, 143197, 143198, 143199, 143200, 143203, 143204, 143205, 143208, 143209, 143210, 143211, 143212, 143213, 143215, 143216, 143217, 143218, 143219, 143220, 143222, 143223, 143226, 143227, 143229, 143230, 143231, 143232, 143234, 143235, 143237, 143238, 143239, 143240, 143241, 143242, 143244, 143245, 143247, 143248, 143250, 143255, 143257, 143258, 143259, 143260, 143261, 143262, 143263, 143264, 143265, 143266, 143267, 143268, 143270, 143271, 143272, 143273, 143275, 143280, 143281, 143282, 143283, 143286, 143288, 143290, 143293, 143295, 143296, 143297, 143298, 143301, 143302, 143303, 143305, 143308, 143309, 143310, 143311, 143312, 143313, 143315, 143316, 143317, 143318, 143319, 143320, 143321, 143322, 143323, 143324, 143325, 143326, 143327, 143328, 143330, 143331, 143333, 143334, 143335, 143336, 143338, 143339, 143340, 143342, 143343, 143345, 143346, 143347, 143349, 143352, 143354, 143355, 143356, 143358, 143359, 143360, 143361, 143362, 143363, 143364, 143365, 143366, 143367, 143368, 143370, 143372, 143375, 143378, 143379, 143380, 143381, 143382, 143383, 143384, 143385, 143389, 143391, 143392, 143394, 143395, 143397, 143398, 143399, 143401, 143402, 143403, 143404, 143405, 143408, 143410, 143411, 143412, 143413, 143415, 143416, 143417, 143418, 143419, 143420, 143421, 143422, 143425, 143426, 143427, 143428, 143429, 143430, 143431, 143432, 143435, 143437, 143438, 143439, 143442, 143444, 143445, 143448, 143449, 143450, 143451, 143454, 143455, 143456, 143457, 143458, 143460, 143461, 143462, 143463, 143464, 143465, 143466, 143467, 143468, 143470, 143472, 143474, 143475, 143476, 143478, 143480, 143481, 143482, 143483, 143484, 143485, 143487, 143488, 143489, 143494, 143497, 143499, 143500, 143502, 143504, 143505, 143506, 143508, 143509, 143510, 143512, 143513, 143514, 143516, 143517, 143518, 143520, 143522, 143525, 143527, 143528, 143529, 143530, 143531, 143532, 143533, 143534, 143535, 143536, 143537, 143538, 143539, 143540, 143541, 143543, 143546, 143547, 143548, 143549, 143550, 143552, 143553, 143554, 143555, 143556, 143557, 143558, 143559, 143560, 143562, 143566, 143567, 143570, 143571, 143572, 143573, 143574, 143575, 143577, 143578, 143579, 143581, 143583, 143584, 143585, 143587, 143588, 143589, 143590, 143591, 143592, 143594, 143596, 143597, 143598, 143599, 143600, 143601, 143602, 143603, 143604, 143605, 143606, 143607, 143608, 143609, 143611, 143612, 143613, 143614, 143616, 143618, 143619, 143620, 143621, 143623, 143624, 143631, 143632, 143633, 143634, 143635, 143639, 143640, 143643, 143644, 143645, 143646, 143648, 143649, 143650, 143651, 143652, 143653, 143654, 143655, 143656, 143658, 143660, 143662, 143664, 143665, 143666, 143667, 143668, 143669, 143671, 143672, 143673, 143675, 143677, 143678, 143679, 143 ...

# %%
    # Extract the overlapping months
    overlapping_months = set(df1['mes_encuesta']).intersection(set(df2['mes_encuesta']))
    
    if not overlapping_months:
        print(f"No overlapping months found between {trimester1} and {trimester2} for the year {year}.")

    # Filter the DataFrames for the overlapping months
    df1_overlap = df1[df1['mes_encuesta'].isin(overlapping_months)]
    df2_overlap = df2[df2['mes_encuesta'].isin(overlapping_months)]
    
    # Compare the IDs for these overlapping months
    common_ids_df1 = df1_overlap['id_identificacion'].unique()
    common_ids_df2 = df2_overlap['id_identificacion'].unique()
    
    common_ids = set(common_ids_df1).intersection(set(common_ids_df2))
    
    print(f"Overlapping months between {trimester1} and {trimester2} for the year {year}: {overlapping_months}")
    print(f"Number of common IDs in overlapping months: {len(common_ids)}")
    print(f"Common IDs: {common_ids}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 17
#      13 common_ids_df2 = df2_overlap['id_identificacion'].unique()
#      15 common_ids = set(common_ids_df1).intersection(set(common_ids_df2))
# ---> 17 print(f"Overlapping months between {trimester1} and {trimester2} for the year {year}: {overlapping_months}")
#      18 print(f"Number of common IDs in overlapping months: {len(common_ids)}")
#      19 print(f"Common IDs: {common_ids}")
#
# NameError: name 'trimester1' is not defined

# %%
import pandas as pd

# Assuming 'trimester_data' is your dictionary of DataFrames
# Example:
# trimester_data = {
#     '3-4-5': df1,
#     '4-5-6': df2,
#     ...
# }

def find_overlapping_ids_for_year(trimester_data, trimester1, trimester2, year):
    # Extract the DataFrames for the specified trimesters
    df1 = trimester_data[trimester1]
    df2 = trimester_data[trimester2]
    
    # Filter the DataFrames for the specified year
    df1 = df1[df1['ano_trimestre'] == year]
    df2 = df2[df2['ano_trimestre'] == year]
    
    # Extract the overlapping months
    overlapping_months = set(df1['mes_encuesta']).intersection(set(df2['mes_encuesta']))
    
    if not overlapping_months:
        print(f"No overlapping months found between {trimester1} and {trimester2} for the year {year}.")
        return None

    # Filter the DataFrames for the overlapping months
    df1_overlap = df1[df1['mes_encuesta'].isin(overlapping_months)]
    df2_overlap = df2[df2['mes_encuesta'].isin(overlapping_months)]
    
    # Compare the IDs for these overlapping months
    common_ids_df1 = df1_overlap['id_identificacion'].unique()
    common_ids_df2 = df2_overlap['id_identificacion'].unique()
    
    common_ids = set(common_ids_df1).intersection(set(common_ids_df2))
    
    print(f"Overlapping months between {trimester1} and {trimester2} for the year {year}: {overlapping_months}")
    print(f"Number of common IDs in overlapping months: {len(common_ids)}")
    print(f"Common IDs: {common_ids}")
    
    return common_ids

# Example usage
year_to_check = 2023
overlapping_ids = find_overlapping_ids_for_year(trimester_data, '3-4-5', '4-5-6', year_to_check)

# If you want to check for multiple pairs of trimesters for a specific year
def check_multiple_pairs_for_year(trimester_data, pairs, year):
    results = {}
    for t1, t2 in pairs:
        common_ids = find_overlapping_ids_for_year(trimester_data, t1, t2, year)
        if common_ids is not None:
            results[(t1, t2)] = common_ids
    return results

# Example pairs to check
pairs_to_check = [('3-4-5', '4-5-6'), ('2-3-4', '3-4-5')]

# Get the results for multiple pairs
multiple_results = check_multiple_pairs_for_year(trimester_data, pairs_to_check, year_to_check)
